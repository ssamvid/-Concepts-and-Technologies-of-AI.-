# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
low = []
moderate = []
high = []
for s, e, sl in time_data:
    if s < 3:
        low.append(s)
    elif 3 <= s < 5:
        moderate.append(s)
    else:
        high.append(s)
print(f"The List for low study time: {low}")
print(f"The List for moderate study time: {moderate}")
print(f"The List for high study time: {high}")
# Out:
# The List for low study time: [2.5, 1.5, 2.0, 2.5]
# The List for moderate study time: [3.5, 4.0, 3.0, 4.5, 3.0, 4.0, 3.5]
# The List for high study time: [5.0, 5.5, 6.0, 5.0]

# %%
print(f"Days for low study: {len(low)}")
print(f"Days for moderate study: {len(moderate)}")
print(f"Days for high study: {len(high)}")
# Out:
# Days for low study: 4
# Days for moderate study: 7
# Days for high study: 4

# %%
study_minutes = []
for x in time_data:
    hour = x[0]
    minute = x * 60
    study_minutes.append(minute)
print(f"The list of study hour in minutes: {minute}")
# Out:
# The list of study hour in minutes: (3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0, 3.5, 2.5, 7.0)

# %%
study_hr = [] 
entertainment_hr = [] 
sleep_hr = []
for x in time_data:
    study_hr.append(x[0])
    entertainment_hr.append(x[1])
    sleep_hr.append(x[2])

avg_study = sum(study_hr)/len(study_hr)
avg_ent = sum(entertainment_hr)/len(entertainment_hr)
avg_sleep = sum(sleep_hr)/len(sleep_hr)
print(f"Average of sleep hour: {avg_study}")    
print(f"Average of entertainment hour: {avg_ent}")   
print(f"Average of sleep hour: {avg_sleep}")
# Out:
# Average of sleep hour: 3.7
# Average of entertainment hour: 2.5
# Average of sleep hour: 7.166666666666667

# %%
import matplotlib.pyplot as plt 

plt.scatter(study_hr, sleep_hr)

plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep ")

plt.show()

# %%
def sum_nested_list(nested_list):
    total = 0

    for item in nested_list:
        if type(item) is list:
            total = total + sum_nested_list(item)
        else:
            total = total + item
    return total

numbers = [1, [2, [3, 4], 5], 6, [100, 8]]
print(sum_nested_list(numbers))
# Out:
# 129

# %%
def generate_permutations(s):

    if len(s) <= 1:
        return [s]

    permutations = []
    used = set()

    for i in range(len(s)):
        ch = s[i]

        if ch in used:
            continue
        used.add(ch)
        rest = s[:i] + s[i+1:]

        for p in generate_permutations(rest):
            permutations.append(ch + p)

    return permutations

print("All permutations of 'abc':", generate_permutations("sam"))
# Out:
# All permutations of 'abc': ['sam', 'sma', 'asm', 'ams', 'msa', 'mas']

# %%
def calculate_directory_size(directory):
    total = 0

    for name, value in directory.items():
        if isinstance(value, dict):
            total += calculate_directory_size(value)
        else:
            total += value

    return total

directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

print("Total size of directory:", calculate_directory_size(directory_structure))
# Out:
# Total size of directory: 1400

# %%
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1

coins = [5, 2, 3]
amount = 15
print("Minimum coins needed to make", amount, "is:", min_coins(coins, amount))
# Out:
# Minimum coins needed to make 15 is: 3

# %%
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0]*(n+1) for _ in range(m+1)]
    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[m][n]

s1 = "samvid"
s2 = "smd"
print(longest_common_subsequence(s1, s2))
# Out:
# 3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [0] * (capacity + 1)
    for i in range(n):
        for w in range(capacity, weights[i]-1, -1):
            dp[w] = max(dp[w], dp[w - weights[i]] + values[i])

    return dp[capacity]
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print(knapsack(weights, values, capacity))
# Out:
# 9
